# %% [markdown]
# # Урок 5
#
# # Парсинг данных. Scrapy. Начало

# %% [markdown]
# ## Загрузим проект

# %%
# !unzip scrapy.zip
# Out:
# Archive:  scrapy.zip
# replace scrapy/project_parser_hh/__init__.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace scrapy/project_parser_hh/items.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace scrapy/project_parser_hh/middlewares.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace scrapy/project_parser_hh/pipelines.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace scrapy/project_parser_hh/runner.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace scrapy/project_parser_hh/settings.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace scrapy/project_parser_hh/spiders/__init__.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace scrapy/project_parser_hh/spiders/hh_ru.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace scrapy/scrapy.cfg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
cd /content/scrapy
# Out:
# /content/scrapy

# %% [markdown]
# ## Установим `mongo` сервер и клиент

# %%
# !apt install mongodb
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# mongodb is already the newest version (1:3.6.9+really3.6.8+90~g8e540c0b6d-0ubuntu5.3).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.

# %%
# !service mongodb start
# Out:
#  * Starting database mongodb
#    ...done.

# %%
# !pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Установим `scrapy`

# %%
# !pip install scrapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Запустим паука

# %%
# !scrapy crawl hh_ru
# Out:
# 2023-01-23 07:41:03 [scrapy.utils.log] INFO: Scrapy 2.7.1 started (bot: project_parser_hh)
# 2023-01-23 07:41:03 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.8.10 (default, Nov 14 2022, 12:59:47) - [GCC 9.4.0], pyOpenSSL 23.0.0 (OpenSSL 3.0.7 1 Nov 2022), cryptography 39.0.0, Platform Linux-5.10.147+-x86_64-with-glibc2.29
# 2023-01-23 07:41:03 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'project_parser_hh',
#  'DOWNLOAD_DELAY': 0.5,
#  'NEWSPIDER_MODULE': 'project_parser_hh.spiders',
#  'SPIDER_MODULES': ['project_parser_hh.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36'}
# /usr/local/lib/python3.8/dist-packages/scrapy/utils/request.py:231: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# ...

# %%
#Создаем паука rabota_ru
# !scrapy genspider rabota_ru rabota_ru
# Out:
# Spider 'rabota_ru' already exists in module:
#   project_parser_hh.spiders.rabota_ru

# %%
# !scrapy crawl rabota_ru
# Out:
# 2023-01-23 07:43:33 [scrapy.utils.log] INFO: Scrapy 2.7.1 started (bot: project_parser_hh)
# 2023-01-23 07:43:33 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.8.10 (default, Nov 14 2022, 12:59:47) - [GCC 9.4.0], pyOpenSSL 23.0.0 (OpenSSL 3.0.7 1 Nov 2022), cryptography 39.0.0, Platform Linux-5.10.147+-x86_64-with-glibc2.29
# 2023-01-23 07:43:33 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'project_parser_hh',
#  'DOWNLOAD_DELAY': 0.5,
#  'NEWSPIDER_MODULE': 'project_parser_hh.spiders',
#  'SPIDER_MODULES': ['project_parser_hh.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36'}
# /usr/local/lib/python3.8/dist-packages/scrapy/utils/request.py:231: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# ...

# %% [markdown]
# ## Проверим, что записалось в базу

# %%
from pymongo import MongoClient

# %%
client = MongoClient()
print(client.list_database_names())
# Out:
# ['admin', 'config', 'local', 'vacancies_python_hh']

# %%
db = client.vacancies_python_hh

print(db.list_collection_names())
# Out:
# ['rabota_ru', 'hh_ru']

# %%
collection_vacancies_hh_ru = db.hh_ru
collection_vacancies_rabota_ru = db.rabota_ru

# %%
vacancies_hh = list(collection_vacancies_hh_ru.find())
vacancies_rabota = list(collection_vacancies_rabota_ru.find())

# %%
len(vacancies_hh), len(vacancies_rabota)

#rabota.ru выдает "похожие вакансии" в том же классе, не разобралась как распарсить именно по запросу
# Out:
# (463, 2456)
