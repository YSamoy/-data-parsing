# %%
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bs4 in /usr/local/lib/python3.8/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from bs4) (4.6.3)

# %%
from bs4 import BeautifulSoup as bs
import requests
from time import  sleep
import re
import json

# %%
url_hh = 'https://novosibirsk.hh.ru/search/vacancy?text=python&from=suggest_post&area=4&hhtmFrom=vacancy_search_list'

headers={
    'User-Agent':	'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36',
        
}

# %%
def hh_parsing():
  vacancy_list_result=[]
  for page in range(200):
    sleep(3) 
    url=url_hh+f'&page={page}'
    response_hh=requests.get(url, headers=headers)
    dom_hh = bs(response_hh.content, 'html.parser')
    vacancies=dom_hh.find_all('div', {'class': 'vacancy-serp-item-body__main-info'})

    vacancy_list=[]
    for vacancy in vacancies:  
      vacancy_name=vacancy.find('a', {'class': 'serp-item__title'}).text
      vacancy_link=vacancy.find('a', {'class': 'serp-item__title'})['href']
      vacancy_salary=vacancy.find('span', {'class': 'bloko-header-section-3'})
      vacancy_employee=vacancy.find('a', {'class': 'bloko-link bloko-link_kind-tertiary'}).text
      
      if vacancy_salary:
        vacancy_salary=vacancy_salary.text.replace('\u202f', '').split(' ')       
        for elements in vacancy_salary:
          if len(vacancy_salary)==4:
            salary_min=vacancy_salary[0]
            salary_max=vacancy_salary[2]
            salary_currency=vacancy_salary[-1]
          elif len(vacancy_salary)==3:
            salary_min=vacancy_salary[1]
            salary_currency=vacancy_salary[-1]
      else:
        salary_min, salary_max, salary_currency=None, None, None


      vacancy_dict={
          'vacancy_name': vacancy_name,
          'vacancy_link': vacancy_link,
          'salary_min': salary_min,
          'salary_max': salary_max,
          'salary_currency': salary_currency,
          'vacancy_employee': vacancy_employee,
          'resource': 'novosibirsk.hh.ru',
    
      }
      vacancy_list.append(vacancy_dict)
    
    if len(vacancy_list)>1:
      vacancy_list_result.append(vacancy_list)
    else:
      with open('vacancy_list_result.json', 'w') as json_hh_parsing:
        json.dump(vacancy_list_result, json_hh_parsing)
      return vacancy_list_result
    

hh_parsing()
# Out:
# [[{'vacancy_name': 'Программист (С++ & Python)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74411422?from=vacancy_search_list&query=python',
#    'salary_min': '100000',
#    'salary_max': '180000',
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'АО\xa0Моделирование и цифровые двойники',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Разработчик Python (R&D)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74176205?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ROBOTMIA',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Разработчик back-end (python)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74365874?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'АО\xa0ИнфоТеКС',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Инженер-программист машинного зрения MV и обработки данных BIGDATA',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74338423?from=vacancy_search_list&query=python',
#    'salary_min': '80000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'ООО\xa0Пин-Программная Интеграция',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Junior Data Scientist (Стажер)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73222503?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Центр финансовых технологий',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Python developer',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/72022422?from=vacancy_search_list&query=python',
#    'salary_min': '80000',
#    'salary_max': '180000',
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'ООО\xa0АйТи Мегастар',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Аналитик данных / Data Scientist (Middle)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73052685?from=vacancy_search_list&query=python',
#    'salary_min': '140000',
#    'salary_max': '200000',
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'Дром',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Sberseasons осень 2022 Data Science Стажер, Новосибирск',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74328310?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Сбер для экспертов',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Разработчик python (Senior/Lead)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73766938?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Eqvanta',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Программист Python',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/70820848?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'it-aces.com',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Исследователь/математик-программист',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74341857?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'CityAir',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Junior Data-scientist',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73930298?from=vacancy_search_list&query=python',
#    'salary_min': '35000',
#    'salary_max': '50000',
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'ООО\xa0Экспасофт',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Data Scientist',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73226688?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ООО\xa0Софт Инжиниринг',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Python разработчик / Отдел анализа и экспертизы',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73758872?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Центр финансовых технологий',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Senior Python developer (remote)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74669733?from=vacancy_search_list&query=python',
#    'salary_min': '250000',
#    'salary_max': '350000',
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'Maklerplan GmbH',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Преподаватель Программирования Python (Yandex лицей)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/69755020?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'МАОУ ОЦ Горностай',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Python developer Middle+',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73870716?from=vacancy_search_list&query=python',
#    'salary_min': '200000',
#    'salary_max': '220000',
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'OWNEX (ООО Консул Групп-Ит)',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Python developer',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73536795?from=vacancy_search_list&query=python',
#    'salary_min': '80000',
#    'salary_max': '180000',
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'ООО\xa0АйТи Мегастар',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Python Developer',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73371410?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'NAN Agency',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'BackEnd разработчик',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73238357?from=vacancy_search_list&query=python',
#    'salary_min': '80000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'Байт-Транзит-Континент',
#    'resource': 'novosibirsk.hh.ru'}],
#  [{'vacancy_name': 'Инженер технического сопровождения и поддержки эксплуатации оборудования',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74184517?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'CityAir',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Преподаватель направления по Мобильным разработкам (Школа Samsung)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/69755207?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'МАОУ ОЦ Горностай',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Technical Lead',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74050477?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ООО\xa0Shortest Track',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'DevSecOps/Security engineer',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/69461765?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ARQA Technologies',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Инженер-программист / Системный администратор',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73978295?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Новосибирский Государственный Технический Университет',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Педагог дополнительного образования по направлению "Разработка VR/AR приложений" в IT-куб',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/53809040?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'МАОУ Лицей №22 Надежда Сибири',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Teamlead Backend',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73402602?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ООО\xa0Инетра',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Преподаватель направления по разработке VR/AR приложений в IT - Куб',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/69755300?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'МАОУ ОЦ Горностай',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Системный администратор (сетевой инженер)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73741917?from=vacancy_search_list&query=python',
#    'salary_min': '50000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'Высший колледж информатики НГУ',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Системный администратор',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73741985?from=vacancy_search_list&query=python',
#    'salary_min': '45000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'Высший колледж информатики НГУ',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Разработчик Hadoop Big Data (стрим Витрины ПИК)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74363978?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Иннотех, Группа компаний',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Руководитель отдела разработки численных методов и математических исследований',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/72231120?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ООО\xa0НТЦ Симмэйкерс',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Инженер по автоматизации тестирования (Cybsi)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74355470?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Positive Technologies',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Программист C',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74180472?from=vacancy_search_list&query=python',
#    'salary_min': '120000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'ООО\xa0ДЕМЛАБС',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'ML-инженер',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/72111803?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Тинькофф',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'DevOps-инженер',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74555680?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ISPsystem',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Senior Data Scientist (WAF)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74252171?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Positive Technologies',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Инженер-программист АСУ ТП',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74402298?from=vacancy_search_list&query=python',
#    'salary_min': '120000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'ООО\xa0Технология',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Инженер технической поддержки',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74012841?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ООО\xa0ВижнЛабс (VisionLabs)',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Senior ML Engineer',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74252311?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Positive Technologies',
#    'resource': 'novosibirsk.hh.ru'}],
#  [{'vacancy_name': 'Инженер Linux',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/71231132?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'АБСОЛЮТ БАНК',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Прикладной администратор (РБС)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/72009504?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Центр финансовых технологий',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Senior/Middle Software Engineer',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73384193?from=vacancy_search_list&query=python',
#    'salary_min': '100000',
#    'salary_max': '350000',
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'Сибирская генерирующая Компания',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Инженер по анализу радиосети',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/75045782?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ПАО\xa0МегаФон, Офис',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'DevOps-инженер в сервис транспорта',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73327163?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': '2ГИС',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Senior Photonics Engineer (integrated optics, optoelectronics, lasers)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73598942?from=vacancy_search_list&query=python',
#    'salary_min': '80000',
#    'salary_max': '120000',
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'ООО\xa0Иннфокус',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Инженер по качеству MP SIEM',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73362831?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Positive Technologies',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'QA Performance',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73683746?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'UserGate',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Системный администратор DevOps (Аккредитованная IT компания)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73228180?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Атом Безопасность',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Эксперт центра управления сетью',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73221515?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ПАО\xa0Ростелеком',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Инженер по качеству (MP10)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73404678?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Positive Technologies',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Аналитик (middle)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73696388?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ООО\xa0Финтех Айкью',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Java developer',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/68372185?from=vacancy_search_list&query=python',
#    'salary_min': '100000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'ООО\xa0Дата Ист',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Программист C#',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/72862686?from=vacancy_search_list&query=python',
#    'salary_min': '100000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'ООО\xa0Дата Ист',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Преподаватель Программирования Java в IT-Куб',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/69755343?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'МАОУ ОЦ Горностай',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Middle backend developer С#/Python (аккредитованная IT-компания)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73342606?from=vacancy_search_list&query=python',
#    'salary_min': '200000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'CityAir',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Эксперт по технологии и моделированию',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73389816?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ПАО\xa0ЯТЭК',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Разработчик ETL',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/69871035?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Тинькофф',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Tech support / инженер технической поддержки',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74042926?from=vacancy_search_list&query=python',
#    'salary_min': '80000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'SmartC',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Senior Data Engineer',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73453345?from=vacancy_search_list&query=python',
#    'salary_min': '250000',
#    'salary_max': '300000',
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'Дром',
#    'resource': 'novosibirsk.hh.ru'}],
#  [{'vacancy_name': 'DevOps инженер',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/67020921?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'IQsоft',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Инженер технической поддержки (Wireless)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/50619305?from=vacancy_search_list&query=python',
#    'salary_min': '120000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'ООО\xa0«Предприятие «ЭЛТЕКС»',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Инженер (техническая поддержка)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/50619288?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ООО\xa0«Предприятие «ЭЛТЕКС»',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Deep Learning Engineer',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/70058603?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Технологика',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Системный администратор',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/68504794?from=vacancy_search_list&query=python',
#    'salary_min': '30000',
#    'salary_max': '50000',
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'ООО\xa0НППГА Луч',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Ведущий инженер-программист технического сопровождения',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73229108?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Nexign (АО Нэксайн)',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Инженер по тестированию (mobile)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/71047831?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Тинькофф',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Middle +/Senior Android разработчик',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/71047939?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Тинькофф',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Junior DevOps-инженер (СберСпасибо)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74025766?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Сбер для экспертов',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'QA engineer',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74071950?from=vacancy_search_list&query=python',
#    'salary_min': '70000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'ООО\xa0Диджитал Клаудс',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Manual QA-инженер в команду Navi',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/71539339?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': '2ГИС',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Ведущий специалист по информационной безопасности',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/69045044?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ЗАО\xa0Группа компаний С7',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Продуктовый аналитик',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74294939?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ООО\xa0Диплей',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Разработчик баз данных',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73504714?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ГРИНМАНИ',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Java developer (онлайн-кинотеатр Movix)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/72415335?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ООО\xa0Эр-1',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'QA Engineer (Management Systems)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/50619284?from=vacancy_search_list&query=python',
#    'salary_min': '120000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'ООО\xa0«Предприятие «ЭЛТЕКС»',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'IT-рекрутер',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74252898?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'VSEMAYKI.RU',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Middle Программист-разработчик AI / Data scientist / NLP Developer (Обработка естественного языка)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73927844?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ООО\xa0Бизнес Цифра',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Web-разработчик',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/74145780?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'АО\xa0Азот-Взрыв',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Сетевой инженер (направление ME)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/50619299?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ООО\xa0«Предприятие «ЭЛТЕКС»',
#    'resource': 'novosibirsk.hh.ru'}],
#  [{'vacancy_name': 'Программист (математик)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/54670368?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Новосибирский государственный университет',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Инженер (математик - программист технической поддержки ПО)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/54668979?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Новосибирский государственный университет',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Программист JS',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73721830?from=vacancy_search_list&query=python',
#    'salary_min': '105000',
#    'salary_max': '215000',
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'Тензор',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Специалист службы поддержки с техническими знаниями (Волкер)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73493045?from=vacancy_search_list&query=python',
#    'salary_min': '15000',
#    'salary_max': '39000',
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'Яндекс',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Аналитик (направление продукты, сегмент B2C)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/72372080?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ПАО\xa0Ростелеком',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Junior-Разработчик С/C++',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/53667946?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'ООО\xa0«Предприятие «ЭЛТЕКС»',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Ведущий специалист технической поддержки (Аккредитованная IT компания)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/70191323?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Атом Безопасность',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Тимлид в команду разработки на Java',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73443917?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Яндекс',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'DevOps специалист',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73287235?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'EXPERO',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'System Administrator (part-time)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73696801?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Velvetech, LLC',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Системный администратор',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73309630?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'АО\xa0Группа страховых компаний Югория',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Тестировщик АБС ЦФТ-Банк',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73431212?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Модульбанк',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Сорсер (Junior IT-рекрутер)',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73490859?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Центр финансовых технологий',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Middle/Senior QA Engineer в Команду BIT',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/72111635?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': '2ГИС',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Преподаватель в школу программирования для детей',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73211433?from=vacancy_search_list&query=python',
#    'salary_min': '50000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'Школа программирования JETCODE',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Middle Computer Vision Engineer',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73309044?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': 'Центр финансовых технологий',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Архитектор поисковых систем С++',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/72366128?from=vacancy_search_list&query=python',
#    'salary_min': '600000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': '2ГИС',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Senior C++ разработчик в Поиск',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/72366478?from=vacancy_search_list&query=python',
#    'salary_min': None,
#    'salary_max': None,
#    'salary_currency': None,
#    'vacancy_employee': '2ГИС',
#    'resource': 'novosibirsk.hh.ru'},
#   {'vacancy_name': 'Аналитик данных',
#    'vacancy_link': 'https://novosibirsk.hh.ru/vacancy/73227411?from=vacancy_search_list&query=python',
#    'salary_min': '150000',
#    'salary_max': None,
#    'salary_currency': 'руб.',
#    'vacancy_employee': 'ООО\xa0ДельтаЛизинг',
#    'resource': 'novosibirsk.hh.ru'}]]
