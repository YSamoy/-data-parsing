# %%
# !apt install mongodb
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# mongodb is already the newest version (1:3.6.9+really3.6.8+90~g8e540c0b6d-0ubuntu5.3).
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.

# %%
# !service mongodb start
# Out:
#  * Starting database mongodb
#    ...done.

# %%
# !pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymongo in /usr/local/lib/python3.8/dist-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from pymongo) (2.2.1)

# %%
from pymongo import MongoClient
import json

file_path = './letters_parser_downloaded.json'
with open(file_path, 'r') as file:
    parsed_letters = json.load(file)

client = MongoClient('mongodb://127.0.0.1:27017/')
db_mail_ru = client.mail_ru

print(client.list_database_names())
# Out:
# ['admin', 'config', 'local', 'mail_ru']

# %%
db_mail_ru.mail_ru.insert_many(parsed_letters)

# %%
letter =db_mail_ru.mail_ru.find()
list(letter)
# Out:
# [{'_id': ObjectId('63d3eeaeee3c9e5bb06cef40'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Tree Views, Dark Forest, Lensa Avatars, React Forms, Conditional CSS',
#   'letter_date_sent': '10 января, 16:10',
#   'letter_text': ['How to create a tree view (collapsible list) using only HTML and CSS.',
#    'Proving you’re a human on a web flooded with generative AI content.',
#    'My avatars were cartoonishly pornified, while my male colleagues got to be astronauts, explorers, and inventors.',
#    'As developers, we don’t like working with forms, but they’re a critical part of most web applications.',
#    'CSS is condtional in many ways. In this article, I will go over a few CSS features that we use every day, and show you how conditional they are.']},
#  {'_id': ObjectId('63d3eeaeee3c9e5bb06cef41'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '📩 Вам письмо от ИТ-предпринимателя Александра Сагуна',
#   'letter_date_sent': '10 января, 13:27',
#   'letter_text': []},
#  {'_id': ObjectId('63d3eeaeee3c9e5bb06cef42'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'All Things AI, 2022 Pens, Mafs, Copy Dennis, Color Spectrum',
#   'letter_date_sent': '9 января, 18:42',
#   'letter_text': ['The Complete Resource Of Artificial Intelligence Tools & Services.',
#    'The number itself is how many people hearted the Pen, but the ranking takes into account heart-levels as well.',
#    'Build interactive, animated visualizations with declarative code.',
#    'This collection is a tribute to all the creators who have taken a little bit too much inspiration from the portfolio website of Dennis Snellenberg.',
#    'Thoughts and resources from years of work exploring color and building tools to work with color.']},
#  {'_id': ObjectId('63d3eeaeee3c9e5bb06cef43'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'Вы довольны своей зарплатой?',
#   'letter_date_sent': '9 января, 14:56',
#   'letter_text': []},
#  {'_id': ObjectId('63d3eeaeee3c9e5bb06cef44'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '💰 Ваш пассивный доход с GeekBrains',
#   'letter_date_sent': '8 января, 13:51',
#   'letter_text': []},
#  {'_id': ObjectId('63d3eeaeee3c9e5bb06cef45'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🟢 Научим выбирать денежную профессию',
#   'letter_date_sent': '7 января, 17:39',
#   'letter_text': []},
#  {'_id': ObjectId('63d3eeaeee3c9e5bb06cef46'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Скидки до -50% на красную икру!',
#   'letter_date_sent': '7 января, 14:41',
#   'letter_text': []},
#  {'_id': ObjectId('63d3eeaeee3c9e5bb06cef47'),
#   'letter_sender': 'Namecheap',
#   'letter_theme': 'Get ready to save up to 96% in our New Year Sale',
#   'letter_date_sent': '7 января, 1:33',
#   'letter_text': []},
#  {'_id': ObjectId('63d3eeaeee3c9e5bb06cef48'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Movie Posters, Typography Trends, Storybook 2023, Data Visualization, AI Revolution',
#   'letter_date_sent': '6 января, 16:10',
#   'letter_text': ['It feels weird to admit this, even to myself, but maybe I love movie poster design even more than I love book covers.',
#    'From code and generative typography to type as a political tool, how and why we create type will be driving what’s coming next.',
#    'Enhanced performance, stability, and some exciting new updates.',
#    'How to choose just the right type of data visualization, with guidelines, best practices and things to keep in mind.',
#    'Artificial intelligence is changing the way we design and the skills required to succeed in the design industry.']},
#  {'_id': ObjectId('63d3eeaeee3c9e5bb06cef49'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'Мы открыли ранний доступ к скидкам',
#   'letter_date_sent': '6 января, 13:59',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab11e'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Tree Views, Dark Forest, Lensa Avatars, React Forms, Conditional CSS',
#   'letter_date_sent': '10 января, 16:10',
#   'letter_text': ['How to create a tree view (collapsible list) using only HTML and CSS.',
#    'Proving you’re a human on a web flooded with generative AI content.',
#    'My avatars were cartoonishly pornified, while my male colleagues got to be astronauts, explorers, and inventors.',
#    'As developers, we don’t like working with forms, but they’re a critical part of most web applications.',
#    'CSS is condtional in many ways. In this article, I will go over a few CSS features that we use every day, and show you how conditional they are.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab11f'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '📩 Вам письмо от ИТ-предпринимателя Александра Сагуна',
#   'letter_date_sent': '10 января, 13:27',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab120'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'All Things AI, 2022 Pens, Mafs, Copy Dennis, Color Spectrum',
#   'letter_date_sent': '9 января, 18:42',
#   'letter_text': ['The Complete Resource Of Artificial Intelligence Tools & Services.',
#    'The number itself is how many people hearted the Pen, but the ranking takes into account heart-levels as well.',
#    'Build interactive, animated visualizations with declarative code.',
#    'This collection is a tribute to all the creators who have taken a little bit too much inspiration from the portfolio website of Dennis Snellenberg.',
#    'Thoughts and resources from years of work exploring color and building tools to work with color.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab121'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'Вы довольны своей зарплатой?',
#   'letter_date_sent': '9 января, 14:56',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab122'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '💰 Ваш пассивный доход с GeekBrains',
#   'letter_date_sent': '8 января, 13:51',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab123'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🟢 Научим выбирать денежную профессию',
#   'letter_date_sent': '7 января, 17:39',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab124'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Скидки до -50% на красную икру!',
#   'letter_date_sent': '7 января, 14:41',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab125'),
#   'letter_sender': 'Namecheap',
#   'letter_theme': 'Get ready to save up to 96% in our New Year Sale',
#   'letter_date_sent': '7 января, 1:33',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab126'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Movie Posters, Typography Trends, Storybook 2023, Data Visualization, AI Revolution',
#   'letter_date_sent': '6 января, 16:10',
#   'letter_text': ['It feels weird to admit this, even to myself, but maybe I love movie poster design even more than I love book covers.',
#    'From code and generative typography to type as a political tool, how and why we create type will be driving what’s coming next.',
#    'Enhanced performance, stability, and some exciting new updates.',
#    'How to choose just the right type of data visualization, with guidelines, best practices and things to keep in mind.',
#    'Artificial intelligence is changing the way we design and the skills required to succeed in the design industry.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab127'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'Мы открыли ранний доступ к скидкам',
#   'letter_date_sent': '6 января, 13:59',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab128'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'У Вас новое личное сообщение [GeekBrains]',
#   'letter_date_sent': '6 января, 10:26',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab129'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Benjamin de Cock, Extinction, Design Systems, ui.land, Inspirational Websites',
#   'letter_date_sent': '5 января, 16:10',
#   'letter_text': ['Ben is a designer who started working for Stripe in 2012 and spent 8 years there, working on many projects including the Stripe home page.',
#    'Extinction crisis puts 1 million species on the verge of disappearing.',
#    '6 different types of design systems.',
#    'The Digital Library for Designers and Engineers.',
#    'A compilation of the most beautifully designed and thoughtfully crafted websites we’ve come across lately.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab12a'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '💫 Какие ИТ-навыки нужны всем в 2023 году',
#   'letter_date_sent': '5 января, 15:22',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab12b'),
#   'letter_sender': 'METRO',
#   'letter_theme': '🔴 До -50% на красную икру и -30% на игристые вина',
#   'letter_date_sent': '5 января, 14:11',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab12c'),
#   'letter_sender': 'Webdesigner News',
#   'letter_theme': 'Latest stories',
#   'letter_date_sent': '5 января, 4:36',
#   'letter_text': ['Generate and sync a full Figma library from Storybook. Less grunt work, more design time!',
#    'When it comes to design, being able to give and receive feedback is key to progressing in your career and forming long and fruitful relationships with clients and teammates. But how exactly can you receive constructive feedback without…',
#    'Dark Sky wasn’t perfect, but it made watching the weather an exceptionally pleasant experience.',
#    'Shopboxo is a free to use e-commerce store builder that lets anyone launch a store in minutes using customisable templates. It is code-free and has payments and delivery integrations in the Philippines.',
#    'My favorite tools that help you perform day-to-day tasks more efficiently.',
#    'If you’re a slabophile — that is a lover of slabs — yet want a typeface that doesn’t look like it was just copied from an old wood-type sampler, then Edie & Eddy Slab designed by Lisa Fischbach for TypeMates maintains the legacy of the…',
#    'View this email in your browser.',
#    'This e-mail has been sent to study.ai_172@mail.ru, click here to unsubscribe.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab12d'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Minimalism, ChatGPT Examples, Shift Happens, FNU, Design Systems',
#   'letter_date_sent': '4 января, 16:10',
#   'letter_text': ['Unlock your own creative taste, and splatter your experiences into a sea of blank canvases',
#    'ChatGPT is an advanced chatbot created by OpenAI, a company that created GPT-3.',
#    'Shift Happens covers 150 years of keyboard history, from the early typewriters to the pixellated keyboards in our pockets.',
#    'In 2013, I applied for a travel visa to the United States. Along with the visa, America, with her boundless generosity, also granted me a new name.',
#    'How we built an RTL-first design system and maintained it during a major redesign.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab12e'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '💬 Учитесь бесплатно',
#   'letter_date_sent': '4 января, 16:07',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab12f'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Sizing Typography, 2022 Dataviz, Mobile UX, ChatGPT Usability Script, Developer Handoff',
#   'letter_date_sent': '3 января, 16:40',
#   'letter_text': ['These t-shirts don’t fit.',
#    'Every year, I pick my favorite data visualization projects, which tend to cover a wide range of purposes but are typically for presentation.',
#    'Fifteen years from the original iPhone, the quality of mobile user experience has stabilized.',
#    'Is artificial intelligence ready to take on UX research work?',
#    'Design handoff can be challenging. It requires clear communication and a shared understanding of the design intent.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab130'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '💥 Начните учиться бесплатно, а не за 250 тыс руб',
#   'letter_date_sent': '3 января, 13:53',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab131'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Tamagui 1.0, SVG Rope, Genders.WTF, Codrops Resources, 2023 Usability',
#   'letter_date_sent': '3 января, 6:40',
#   'letter_text': ['Ship cross-platform React apps in ½ the time with 2x performance.',
#    'This is an interactive article. To fully experience it, you’ll need to turn JavaScript on. Today, I’ll take you through the process I came up with …',
#    'A collection of gender forms fails from across the web.',
#    'A roundup of selected Codrops articles and tutorials of the year 2022.',
#    'This is how people behave on the web in 2023.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab132'),
#   'letter_sender': 'METRO',
#   'letter_theme': '-30% на все игристые вина региона Шампань при покупке от 3-х бутылок!🍾',
#   'letter_date_sent': '2 января, 14:47',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab133'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🚨 Ургант + GeekBrains =',
#   'letter_date_sent': '2 января, 13:45',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab134'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'У Вас новое личное сообщение [GeekBrains]',
#   'letter_date_sent': '2 января, 5:06',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab135'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'У Вас новое личное сообщение [GeekBrains]',
#   'letter_date_sent': '6 января, 10:26',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab136'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Benjamin de Cock, Extinction, Design Systems, ui.land, Inspirational Websites',
#   'letter_date_sent': '5 января, 16:10',
#   'letter_text': ['Ben is a designer who started working for Stripe in 2012 and spent 8 years there, working on many projects including the Stripe home page.',
#    'Extinction crisis puts 1 million species on the verge of disappearing.',
#    '6 different types of design systems.',
#    'The Digital Library for Designers and Engineers.',
#    'A compilation of the most beautifully designed and thoughtfully crafted websites we’ve come across lately.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab137'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '💫 Какие ИТ-навыки нужны всем в 2023 году',
#   'letter_date_sent': '5 января, 15:22',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab138'),
#   'letter_sender': 'METRO',
#   'letter_theme': '🔴 До -50% на красную икру и -30% на игристые вина',
#   'letter_date_sent': '5 января, 14:11',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab139'),
#   'letter_sender': 'Webdesigner News',
#   'letter_theme': 'Latest stories',
#   'letter_date_sent': '5 января, 4:36',
#   'letter_text': ['Generate and sync a full Figma library from Storybook. Less grunt work, more design time!',
#    'When it comes to design, being able to give and receive feedback is key to progressing in your career and forming long and fruitful relationships with clients and teammates. But how exactly can you receive constructive feedback without…',
#    'Dark Sky wasn’t perfect, but it made watching the weather an exceptionally pleasant experience.',
#    'Shopboxo is a free to use e-commerce store builder that lets anyone launch a store in minutes using customisable templates. It is code-free and has payments and delivery integrations in the Philippines.',
#    'My favorite tools that help you perform day-to-day tasks more efficiently.',
#    'If you’re a slabophile — that is a lover of slabs — yet want a typeface that doesn’t look like it was just copied from an old wood-type sampler, then Edie & Eddy Slab designed by Lisa Fischbach for TypeMates maintains the legacy of the…',
#    'View this email in your browser.',
#    'This e-mail has been sent to study.ai_172@mail.ru, click here to unsubscribe.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab13a'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Minimalism, ChatGPT Examples, Shift Happens, FNU, Design Systems',
#   'letter_date_sent': '4 января, 16:10',
#   'letter_text': ['Unlock your own creative taste, and splatter your experiences into a sea of blank canvases',
#    'ChatGPT is an advanced chatbot created by OpenAI, a company that created GPT-3.',
#    'Shift Happens covers 150 years of keyboard history, from the early typewriters to the pixellated keyboards in our pockets.',
#    'In 2013, I applied for a travel visa to the United States. Along with the visa, America, with her boundless generosity, also granted me a new name.',
#    'How we built an RTL-first design system and maintained it during a major redesign.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab13b'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '💬 Учитесь бесплатно',
#   'letter_date_sent': '4 января, 16:07',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab13c'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Sizing Typography, 2022 Dataviz, Mobile UX, ChatGPT Usability Script, Developer Handoff',
#   'letter_date_sent': '3 января, 16:40',
#   'letter_text': ['These t-shirts don’t fit.',
#    'Every year, I pick my favorite data visualization projects, which tend to cover a wide range of purposes but are typically for presentation.',
#    'Fifteen years from the original iPhone, the quality of mobile user experience has stabilized.',
#    'Is artificial intelligence ready to take on UX research work?',
#    'Design handoff can be challenging. It requires clear communication and a shared understanding of the design intent.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab13d'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '💥 Начните учиться бесплатно, а не за 250 тыс руб',
#   'letter_date_sent': '3 января, 13:53',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab13e'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Tamagui 1.0, SVG Rope, Genders.WTF, Codrops Resources, 2023 Usability',
#   'letter_date_sent': '3 января, 6:40',
#   'letter_text': ['Ship cross-platform React apps in ½ the time with 2x performance.',
#    'This is an interactive article. To fully experience it, you’ll need to turn JavaScript on. Today, I’ll take you through the process I came up with …',
#    'A collection of gender forms fails from across the web.',
#    'A roundup of selected Codrops articles and tutorials of the year 2022.',
#    'This is how people behave on the web in 2023.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab13f'),
#   'letter_sender': 'METRO',
#   'letter_theme': '-30% на все игристые вина региона Шампань при покупке от 3-х бутылок!🍾',
#   'letter_date_sent': '2 января, 14:47',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab140'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🚨 Ургант + GeekBrains =',
#   'letter_date_sent': '2 января, 13:45',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab141'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'У Вас новое личное сообщение [GeekBrains]',
#   'letter_date_sent': '2 января, 5:06',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab142'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'Что мы внедрили в обучение в 2022 году',
#   'letter_date_sent': '1 января, 14:55',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab143'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'Итоги-2022 в цифрах и фактах',
#   'letter_date_sent': '31 декабря 2022, 13:06',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab144'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Outlook Redesign, CSS Subgrid, CSS Things, Framer Awards, Visual Stories',
#   'letter_date_sent': '30 декабря 2022, 19:08',
#   'letter_text': ['Our design journey to modernize Outlook.',
#    'With subgrid coming to all engines very soon, it’s a great time to discover what this new feature of grid can do.',
#    'Just a couple of ideas!',
#    'Want to participate and have your site considered for a prize? Submit it before the end of the year to be nominated.',
#    'Selected New York Times graphics, visualizations and multimedia stories published this year.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab145'),
#   'letter_sender': 'METRO',
#   'letter_theme': '❄️ Щедрые предложения к Новому году!',
#   'letter_date_sent': '30 декабря 2022, 17:29',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab146'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🧠 Кем работать в 2023 году',
#   'letter_date_sent': '30 декабря 2022, 12:50',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab147'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Machines Change Art, Wrap Balancer, Event Apart, Designers & AI, 2022 Tools',
#   'letter_date_sent': '30 декабря 2022, 6:36',
#   'letter_text': ['At a few times in history, new technologies came along that changed the way we make art.',
#    'Simple React Component That Makes Titles More Readable',
#    'Seventeen years ago, in December 2005, we held our first conference in Philadelphia. The event we just held in San Francisco was our last.',
#    'Existing and future use-cases for AI in web and product design.',
#    'Here’s how and which apps and tools tech teams all over the world used.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab148'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'Как гарантированно найти работу в 2023-м',
#   'letter_date_sent': '29 декабря 2022, 10:39',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab149'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Skewed Highlight, Microsoft Designer, Container Size Queries, PDF Accessibility, Situation Designer',
#   'letter_date_sent': '28 декабря 2022, 16:11',
#   'letter_text': ['Recently Sacha Greif challenged his Twitter followers to code a fancy highlighter effect using only CSS. I took the bait and started coding!',
#    'Observations on Microsoft Designer and OpenAI’s DALLE-2, forming approaches and possible principles for designing for AI image prompts.',
#    'CSS Container Queries are still gaining traction and many of us are getting our hands wet with them.',
#    'Access to content is more important than format.',
#    'How might we train a model to recognize something in the physical world that currently exists purely as a design?']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab14a'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Щедрые скидки до -50% с 29-31 декабря!',
#   'letter_date_sent': '28 декабря 2022, 16:09',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab14b'),
#   'letter_sender': '🎄 GeekBrains',
#   'letter_theme': '😱 Последний день низких цен',
#   'letter_date_sent': '28 декабря 2022, 13:48',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab14c'),
#   'letter_sender': 'METRO',
#   'letter_theme': '-30% на все игристые вина региона Шампань при покупке от 3-х бутылок!🍾',
#   'letter_date_sent': '2 января, 14:47',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab14d'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🚨 Ургант + GeekBrains =',
#   'letter_date_sent': '2 января, 13:45',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab14e'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'У Вас новое личное сообщение [GeekBrains]',
#   'letter_date_sent': '2 января, 5:06',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab14f'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'Что мы внедрили в обучение в 2022 году',
#   'letter_date_sent': '1 января, 14:55',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab150'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'Итоги-2022 в цифрах и фактах',
#   'letter_date_sent': '31 декабря 2022, 13:06',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab151'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Outlook Redesign, CSS Subgrid, CSS Things, Framer Awards, Visual Stories',
#   'letter_date_sent': '30 декабря 2022, 19:08',
#   'letter_text': ['Our design journey to modernize Outlook.',
#    'With subgrid coming to all engines very soon, it’s a great time to discover what this new feature of grid can do.',
#    'Just a couple of ideas!',
#    'Want to participate and have your site considered for a prize? Submit it before the end of the year to be nominated.',
#    'Selected New York Times graphics, visualizations and multimedia stories published this year.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab152'),
#   'letter_sender': 'METRO',
#   'letter_theme': '❄️ Щедрые предложения к Новому году!',
#   'letter_date_sent': '30 декабря 2022, 17:29',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab153'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🧠 Кем работать в 2023 году',
#   'letter_date_sent': '30 декабря 2022, 12:50',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab154'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Machines Change Art, Wrap Balancer, Event Apart, Designers & AI, 2022 Tools',
#   'letter_date_sent': '30 декабря 2022, 6:36',
#   'letter_text': ['At a few times in history, new technologies came along that changed the way we make art.',
#    'Simple React Component That Makes Titles More Readable',
#    'Seventeen years ago, in December 2005, we held our first conference in Philadelphia. The event we just held in San Francisco was our last.',
#    'Existing and future use-cases for AI in web and product design.',
#    'Here’s how and which apps and tools tech teams all over the world used.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab155'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'Как гарантированно найти работу в 2023-м',
#   'letter_date_sent': '29 декабря 2022, 10:39',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab156'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Skewed Highlight, Microsoft Designer, Container Size Queries, PDF Accessibility, Situation Designer',
#   'letter_date_sent': '28 декабря 2022, 16:11',
#   'letter_text': ['Recently Sacha Greif challenged his Twitter followers to code a fancy highlighter effect using only CSS. I took the bait and started coding!',
#    'Observations on Microsoft Designer and OpenAI’s DALLE-2, forming approaches and possible principles for designing for AI image prompts.',
#    'CSS Container Queries are still gaining traction and many of us are getting our hands wet with them.',
#    'Access to content is more important than format.',
#    'How might we train a model to recognize something in the physical world that currently exists purely as a design?']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab157'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Щедрые скидки до -50% с 29-31 декабря!',
#   'letter_date_sent': '28 декабря 2022, 16:09',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab158'),
#   'letter_sender': '🎄 GeekBrains',
#   'letter_theme': '😱 Последний день низких цен',
#   'letter_date_sent': '28 декабря 2022, 13:48',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab159'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'У Вас новое личное сообщение [GeekBrains]',
#   'letter_date_sent': '27 декабря 2022, 20:04',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab15a'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Adaptive Accessories, Counting Visitors, Reading Design, Rudolph Typography, Trans Inclusion',
#   'letter_date_sent': '27 декабря 2022, 16:11',
#   'letter_text': ['How we’re designing assisted devices to give everyone access to the future.',
#    'Building a web analytics service without cookies poses a tricky problem: How do you distinguish unique visitors?',
#    'An archive of critical writing about design. From architecture and urbanism to product, fashion, graphic and beyond.',
#    'The classic Christmas TV special opens with letterforms that can be traced back to the Lettera alphabet book series.',
#    'Answering trans people’s needs online can create a safer digital environment and lead to a more diverse workforce in Tech.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab15b'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🎨 Мама, я в дизайне',
#   'letter_date_sent': '27 декабря 2022, 16:03',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab15c'),
#   'letter_sender': 'Команда Mail.ru',
#   'letter_theme': 'Душевное письмо 💌',
#   'letter_date_sent': '27 декабря 2022, 16:01',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab15d'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Вам письмо ✨',
#   'letter_date_sent': '27 декабря 2022, 15:23',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab15e'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Logical Properties, Jazz.Computer, Mesher, Interactions & Animations, Readymag Round-Up',
#   'letter_date_sent': '26 декабря 2022, 16:11',
#   'letter_text': ['You may have already heard of CSS logical properties or RTL adaptations but are still deciding whether to deploy them widely.',
#    'Interactive Music. Scroll to play.',
#    'A free tool to create beautiful mesh gradients only with CSS code.',
#    'Looking for a fresh burst of animation inspiration? Check out this new collection of creative Dribbble shots.',
#    'In its 2022 round-up, Readymag recalls the most significant updates of the year and offers a sneak peek at its plans for 2023.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab15f'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🔗 Вы кое-что упустили в 2022-м',
#   'letter_date_sent': '26 декабря 2022, 15:42',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab160'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🔮🃏Что ждет вас в 2023 году',
#   'letter_date_sent': '25 декабря 2022, 12:40',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab161'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🖇 Как применяют диджитал-технологии',
#   'letter_date_sent': '24 декабря 2022, 14:09',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab162'),
#   'letter_sender': 'Mail.ru',
#   'letter_theme': 'Изменён пароль в аккаунте',
#   'letter_date_sent': '24 декабря 2022, 3:18',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab163'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Skewed Highlight, Microsoft Designer, Container Size Queries, PDF Accessibility, Situation Designer',
#   'letter_date_sent': '28 декабря 2022, 16:11',
#   'letter_text': ['Recently Sacha Greif challenged his Twitter followers to code a fancy highlighter effect using only CSS. I took the bait and started coding!',
#    'Observations on Microsoft Designer and OpenAI’s DALLE-2, forming approaches and possible principles for designing for AI image prompts.',
#    'CSS Container Queries are still gaining traction and many of us are getting our hands wet with them.',
#    'Access to content is more important than format.',
#    'How might we train a model to recognize something in the physical world that currently exists purely as a design?']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab164'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Щедрые скидки до -50% с 29-31 декабря!',
#   'letter_date_sent': '28 декабря 2022, 16:09',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab165'),
#   'letter_sender': '🎄 GeekBrains',
#   'letter_theme': '😱 Последний день низких цен',
#   'letter_date_sent': '28 декабря 2022, 13:48',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab166'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'У Вас новое личное сообщение [GeekBrains]',
#   'letter_date_sent': '27 декабря 2022, 20:04',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab167'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Adaptive Accessories, Counting Visitors, Reading Design, Rudolph Typography, Trans Inclusion',
#   'letter_date_sent': '27 декабря 2022, 16:11',
#   'letter_text': ['How we’re designing assisted devices to give everyone access to the future.',
#    'Building a web analytics service without cookies poses a tricky problem: How do you distinguish unique visitors?',
#    'An archive of critical writing about design. From architecture and urbanism to product, fashion, graphic and beyond.',
#    'The classic Christmas TV special opens with letterforms that can be traced back to the Lettera alphabet book series.',
#    'Answering trans people’s needs online can create a safer digital environment and lead to a more diverse workforce in Tech.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab168'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🎨 Мама, я в дизайне',
#   'letter_date_sent': '27 декабря 2022, 16:03',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab169'),
#   'letter_sender': 'Команда Mail.ru',
#   'letter_theme': 'Душевное письмо 💌',
#   'letter_date_sent': '27 декабря 2022, 16:01',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab16a'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Вам письмо ✨',
#   'letter_date_sent': '27 декабря 2022, 15:23',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab16b'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Logical Properties, Jazz.Computer, Mesher, Interactions & Animations, Readymag Round-Up',
#   'letter_date_sent': '26 декабря 2022, 16:11',
#   'letter_text': ['You may have already heard of CSS logical properties or RTL adaptations but are still deciding whether to deploy them widely.',
#    'Interactive Music. Scroll to play.',
#    'A free tool to create beautiful mesh gradients only with CSS code.',
#    'Looking for a fresh burst of animation inspiration? Check out this new collection of creative Dribbble shots.',
#    'In its 2022 round-up, Readymag recalls the most significant updates of the year and offers a sneak peek at its plans for 2023.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab16c'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🔗 Вы кое-что упустили в 2022-м',
#   'letter_date_sent': '26 декабря 2022, 15:42',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab16d'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🔮🃏Что ждет вас в 2023 году',
#   'letter_date_sent': '25 декабря 2022, 12:40',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab16e'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🖇 Как применяют диджитал-технологии',
#   'letter_date_sent': '24 декабря 2022, 14:09',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab16f'),
#   'letter_sender': 'Mail.ru',
#   'letter_theme': 'Изменён пароль в аккаунте',
#   'letter_date_sent': '24 декабря 2022, 3:18',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab170'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Book Covers, Super Rich, Widlife Comedy, 2022 CSS Updates, Vignelli Canon',
#   'letter_date_sent': '23 декабря 2022, 16:11',
#   'letter_text': ['The best book covers of the year—as chosen by some of the industry’s best book cover designers.',
#    'Why some mathematicians argue the economy is designed to create a few super rich people – unless we stop it.',
#    '2022 Competition Winners.',
#    'Review (nearly) eleven exciting additions to CSS that became fully or nearly cross-browser in 2022!',
#    'Massimo Vignelli, the multi-faceted designer and thinker, was the last of the great modernist designers.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab171'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🎁 2 профессии по цене 1',
#   'letter_date_sent': '23 декабря 2022, 16:02',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab172'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'До -40% на крепкое и до -30% на красную икру!',
#   'letter_date_sent': '22 декабря 2022, 23:54',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab173'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'UX Science, Performance Inequality Gap, Flash in 2022, Leica Books, Web Research',
#   'letter_date_sent': '22 декабря 2022, 16:11',
#   'letter_text': ['Behind the design and evaluation of user-centered products are the methodologies, techniques, and deliverables of the UX design process.',
#    "When digital is society's default, slow is exclusionary.",
#    "When Adobe killed Flash Player in 2020, I didn't want my Flash games to disappear forever.",
#    'These three books have helped me understand in words what was previously just a feeling — why I love Leica cameras.',
#    'We’ve started making a tradition of rounding up the latest front-end research at the end of each year.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab174'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🎁 5 бесплатных курсов',
#   'letter_date_sent': '22 декабря 2022, 14:28',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab175'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'У Вас новое личное сообщение [GeekBrains]',
#   'letter_date_sent': '22 декабря 2022, 3:21',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab176'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Art Movements, Stop Stealing Sheep, Emotional Awareness, Time-Zone Selectors, AI-Powered UIs',
#   'letter_date_sent': '21 декабря 2022, 16:11',
#   'letter_text': ['The first piece of visual art in history is from 40,000 years ago.',
#    'Type design legend Erik Spiekermann has teamed up with Google Fonts to make the new edition of his book “Stop Stealing Sheep” available to all.',
#    'A journey of emotional awareness, where we uncover the power of naming and visualizing your feelings.',
#    'Users often struggle to find their time zone from a time-zone selector.',
#    'Will AI eventually replace us in the field of interface design?']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab177'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '📈 Цены вырастут, но не для вас',
#   'letter_date_sent': '21 декабря 2022, 11:50',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab178'),
#   'letter_sender': 'Mail.ru',
#   'letter_theme': 'Вход с нового устройства в аккаунт',
#   'letter_date_sent': '21 декабря 2022, 11:14',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab179'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Тук-тук! 2000 бонусных рублей ждут вас!',
#   'letter_date_sent': '20 декабря 2022, 18:56',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab17a'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🔮🃏Что ждет вас в 2023 году',
#   'letter_date_sent': '25 декабря 2022, 12:40',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab17b'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🖇 Как применяют диджитал-технологии',
#   'letter_date_sent': '24 декабря 2022, 14:09',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab17c'),
#   'letter_sender': 'Mail.ru',
#   'letter_theme': 'Изменён пароль в аккаунте',
#   'letter_date_sent': '24 декабря 2022, 3:18',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab17d'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Book Covers, Super Rich, Widlife Comedy, 2022 CSS Updates, Vignelli Canon',
#   'letter_date_sent': '23 декабря 2022, 16:11',
#   'letter_text': ['The best book covers of the year—as chosen by some of the industry’s best book cover designers.',
#    'Why some mathematicians argue the economy is designed to create a few super rich people – unless we stop it.',
#    '2022 Competition Winners.',
#    'Review (nearly) eleven exciting additions to CSS that became fully or nearly cross-browser in 2022!',
#    'Massimo Vignelli, the multi-faceted designer and thinker, was the last of the great modernist designers.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab17e'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🎁 2 профессии по цене 1',
#   'letter_date_sent': '23 декабря 2022, 16:02',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab17f'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'До -40% на крепкое и до -30% на красную икру!',
#   'letter_date_sent': '22 декабря 2022, 23:54',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab180'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'UX Science, Performance Inequality Gap, Flash in 2022, Leica Books, Web Research',
#   'letter_date_sent': '22 декабря 2022, 16:11',
#   'letter_text': ['Behind the design and evaluation of user-centered products are the methodologies, techniques, and deliverables of the UX design process.',
#    "When digital is society's default, slow is exclusionary.",
#    "When Adobe killed Flash Player in 2020, I didn't want my Flash games to disappear forever.",
#    'These three books have helped me understand in words what was previously just a feeling — why I love Leica cameras.',
#    'We’ve started making a tradition of rounding up the latest front-end research at the end of each year.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab181'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🎁 5 бесплатных курсов',
#   'letter_date_sent': '22 декабря 2022, 14:28',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab182'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'У Вас новое личное сообщение [GeekBrains]',
#   'letter_date_sent': '22 декабря 2022, 3:21',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab183'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Art Movements, Stop Stealing Sheep, Emotional Awareness, Time-Zone Selectors, AI-Powered UIs',
#   'letter_date_sent': '21 декабря 2022, 16:11',
#   'letter_text': ['The first piece of visual art in history is from 40,000 years ago.',
#    'Type design legend Erik Spiekermann has teamed up with Google Fonts to make the new edition of his book “Stop Stealing Sheep” available to all.',
#    'A journey of emotional awareness, where we uncover the power of naming and visualizing your feelings.',
#    'Users often struggle to find their time zone from a time-zone selector.',
#    'Will AI eventually replace us in the field of interface design?']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab184'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '📈 Цены вырастут, но не для вас',
#   'letter_date_sent': '21 декабря 2022, 11:50',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab185'),
#   'letter_sender': 'Mail.ru',
#   'letter_theme': 'Вход с нового устройства в аккаунт',
#   'letter_date_sent': '21 декабря 2022, 11:14',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab186'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Тук-тук! 2000 бонусных рублей ждут вас!',
#   'letter_date_sent': '20 декабря 2022, 18:56',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab187'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🧠 Стартуйте в дизайне за 116 ₽ в день',
#   'letter_date_sent': '20 декабря 2022, 18:55',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab188'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'MAR1D, Attracting Recruiters, Material 2022, CSS Nesting, Style Queries',
#   'letter_date_sent': '20 декабря 2022, 16:11',
#   'letter_text': ['Mario in 1 dimension.',
#    'Understand how recruiters source candidates on LinkedIn and how to optimize your profile to improve your chances of being found.',
#    'Some of Material Design’s top moments from the past year.',
#    'The CSS Working Group is continuing a debate over the best way to define nesting in CSS.',
#    'A look at CSS container style queries.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab189'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '💥 Последнее Geek-шоу года!',
#   'letter_date_sent': '19 декабря 2022, 20:48',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab18a'),
#   'letter_sender': 'METRO',
#   'letter_theme': '🎁 Призовой фонд 100 000 рублей 🎁',
#   'letter_date_sent': '19 декабря 2022, 18:00',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab18b'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Это – на Новый год!',
#   'letter_date_sent': '19 декабря 2022, 17:56',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab18c'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Book Covers, Klingspor Type, MuseScore 4, 3D Sliders, Design Ownership',
#   'letter_date_sent': '19 декабря 2022, 16:11',
#   'letter_text': ['The book cover is one of my all-time favorite design objects and a big part of the reason I love going to bookstores.',
#    'She stock of historical material from the former type foundry Gebr. Klingspor in Offenbach.',
#    'In this video, I take you through how we built the team; how we made design decisions and how we improved playback & engraving quality.',
#    'In this series, we’ve been making image sliders with nothing but HTML and CSS.',
#    'What are you allowed to do with other designers’ work?']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab18d'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🔴 Директора GeekBrains ждут вас в 18:00',
#   'letter_date_sent': '19 декабря 2022, 13:17',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab18e'),
#   'letter_sender': 'Namecheap',
#   'letter_theme': 'HURRY — our Holiday Deals are almost over!',
#   'letter_date_sent': '19 декабря 2022, 0:31',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab18f'),
#   'letter_sender': 'Webdesigner News',
#   'letter_theme': 'Latest stories',
#   'letter_date_sent': '18 декабря 2022, 21:05',
#   'letter_text': ['Get Over 500+ Website Design and Development RFPs from High Quality Organizations Delivered to Your Inbox Each Year.',
#    'As the year comes to a close, I’ve been reflecting on the various streams of income that I’ve added to my business this year. While each has been valuable in its own way, one that has stood out is starting my own online course.',
#    'In the age of artificial intelligence the ability to generate realistic images from text prompts is no longer a distant futuristic concept—it’s a present-day reality.',
#    'To take on Google, You.com opens its search engine to third-party developers.',
#    'A Curated Collection of AI-generated Abstract 3D Shapes.',
#    'Watching what users do, not just what you think they’ll do can transform your customer experience. And often a tiny tweak makes a huge difference to the bottom line. ',
#    'View this email in your browser.',
#    'This e-mail has been sent to study.ai_172@mail.ru, click here to unsubscribe.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab190'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🎁 Забирайте iPhone 14 и другие подарки',
#   'letter_date_sent': '18 декабря 2022, 15:11',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab191'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '📈 Цены вырастут, но не для вас',
#   'letter_date_sent': '21 декабря 2022, 11:50',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab192'),
#   'letter_sender': 'Mail.ru',
#   'letter_theme': 'Вход с нового устройства в аккаунт',
#   'letter_date_sent': '21 декабря 2022, 11:14',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab193'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Тук-тук! 2000 бонусных рублей ждут вас!',
#   'letter_date_sent': '20 декабря 2022, 18:56',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab194'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🧠 Стартуйте в дизайне за 116 ₽ в день',
#   'letter_date_sent': '20 декабря 2022, 18:55',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab195'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'MAR1D, Attracting Recruiters, Material 2022, CSS Nesting, Style Queries',
#   'letter_date_sent': '20 декабря 2022, 16:11',
#   'letter_text': ['Mario in 1 dimension.',
#    'Understand how recruiters source candidates on LinkedIn and how to optimize your profile to improve your chances of being found.',
#    'Some of Material Design’s top moments from the past year.',
#    'The CSS Working Group is continuing a debate over the best way to define nesting in CSS.',
#    'A look at CSS container style queries.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab196'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '💥 Последнее Geek-шоу года!',
#   'letter_date_sent': '19 декабря 2022, 20:48',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab197'),
#   'letter_sender': 'METRO',
#   'letter_theme': '🎁 Призовой фонд 100 000 рублей 🎁',
#   'letter_date_sent': '19 декабря 2022, 18:00',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab198'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Это – на Новый год!',
#   'letter_date_sent': '19 декабря 2022, 17:56',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab199'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Book Covers, Klingspor Type, MuseScore 4, 3D Sliders, Design Ownership',
#   'letter_date_sent': '19 декабря 2022, 16:11',
#   'letter_text': ['The book cover is one of my all-time favorite design objects and a big part of the reason I love going to bookstores.',
#    'She stock of historical material from the former type foundry Gebr. Klingspor in Offenbach.',
#    'In this video, I take you through how we built the team; how we made design decisions and how we improved playback & engraving quality.',
#    'In this series, we’ve been making image sliders with nothing but HTML and CSS.',
#    'What are you allowed to do with other designers’ work?']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab19a'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🔴 Директора GeekBrains ждут вас в 18:00',
#   'letter_date_sent': '19 декабря 2022, 13:17',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab19b'),
#   'letter_sender': 'Namecheap',
#   'letter_theme': 'HURRY — our Holiday Deals are almost over!',
#   'letter_date_sent': '19 декабря 2022, 0:31',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab19c'),
#   'letter_sender': 'Webdesigner News',
#   'letter_theme': 'Latest stories',
#   'letter_date_sent': '18 декабря 2022, 21:05',
#   'letter_text': ['Get Over 500+ Website Design and Development RFPs from High Quality Organizations Delivered to Your Inbox Each Year.',
#    'As the year comes to a close, I’ve been reflecting on the various streams of income that I’ve added to my business this year. While each has been valuable in its own way, one that has stood out is starting my own online course.',
#    'In the age of artificial intelligence the ability to generate realistic images from text prompts is no longer a distant futuristic concept—it’s a present-day reality.',
#    'To take on Google, You.com opens its search engine to third-party developers.',
#    'A Curated Collection of AI-generated Abstract 3D Shapes.',
#    'Watching what users do, not just what you think they’ll do can transform your customer experience. And often a tiny tweak makes a huge difference to the bottom line. ',
#    'View this email in your browser.',
#    'This e-mail has been sent to study.ai_172@mail.ru, click here to unsubscribe.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab19d'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🎁 Забирайте iPhone 14 и другие подарки',
#   'letter_date_sent': '18 декабря 2022, 15:11',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab19e'),
#   'letter_sender': 'METRO',
#   'letter_theme': '⏰ Щедрые скидки завтра заканчиваются!',
#   'letter_date_sent': '17 декабря 2022, 15:25',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab19f'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '💻🤧 Ваш компьютер болен',
#   'letter_date_sent': '17 декабря 2022, 14:22',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1a0'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Logical Border Radius, iA Presenter Identity, Storybook 7.0, Redesigning Twitter, Oldřich Menhart',
#   'letter_date_sent': '17 декабря 2022, 7:13',
#   'letter_text': ['Logical properties typically refer to the inline or block axis, which are different depending on the direction or writing mode.',
#    'Defining the identity of iA Presenter next to iA Writer was a three-year process that went hand-in-hand with the UI development.',
#    'Re-architected codebase for performance, stability, and 100s of improvements.',
#    'As Elon Musk burns down the Twitter we know, will a drastically different user experience emerge from the ashes?',
#    "On the 125th anniversary of his birth a project to digitize some of the Czech designer's iconic typefaces."]},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1a1'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'У Вас новое личное сообщение [GeekBrains]',
#   'letter_date_sent': '17 декабря 2022, 3:22',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1a2'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Скидка 300 рублей на первый заказ🍏',
#   'letter_date_sent': '16 декабря 2022, 21:24',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1a3'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Адвент-календарь скидок в METRO!',
#   'letter_date_sent': '16 декабря 2022, 19:02',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1a4'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '💬 Обучение за 0 рублей',
#   'letter_date_sent': '16 декабря 2022, 12:53',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1a5'),
#   'letter_sender': 'CSS Weekly',
#   'letter_theme': 'Issue #534: The State of CSS 2022, CSS image()',
#   'letter_date_sent': '16 декабря 2022, 5:51',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1a6'),
#   'letter_sender': 'Namecheap',
#   'letter_theme': 'How to manage your website like a pro, for less',
#   'letter_date_sent': '15 декабря 2022, 20:48',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1a7'),
#   'letter_sender': 'Namecheap',
#   'letter_theme': 'HURRY — our Holiday Deals are almost over!',
#   'letter_date_sent': '19 декабря 2022, 0:31',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1a8'),
#   'letter_sender': 'Webdesigner News',
#   'letter_theme': 'Latest stories',
#   'letter_date_sent': '18 декабря 2022, 21:05',
#   'letter_text': ['Get Over 500+ Website Design and Development RFPs from High Quality Organizations Delivered to Your Inbox Each Year.',
#    'As the year comes to a close, I’ve been reflecting on the various streams of income that I’ve added to my business this year. While each has been valuable in its own way, one that has stood out is starting my own online course.',
#    'In the age of artificial intelligence the ability to generate realistic images from text prompts is no longer a distant futuristic concept—it’s a present-day reality.',
#    'To take on Google, You.com opens its search engine to third-party developers.',
#    'A Curated Collection of AI-generated Abstract 3D Shapes.',
#    'Watching what users do, not just what you think they’ll do can transform your customer experience. And often a tiny tweak makes a huge difference to the bottom line. ',
#    'View this email in your browser.',
#    'This e-mail has been sent to study.ai_172@mail.ru, click here to unsubscribe.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1a9'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🎁 Забирайте iPhone 14 и другие подарки',
#   'letter_date_sent': '18 декабря 2022, 15:11',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1aa'),
#   'letter_sender': 'METRO',
#   'letter_theme': '⏰ Щедрые скидки завтра заканчиваются!',
#   'letter_date_sent': '17 декабря 2022, 15:25',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1ab'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '💻🤧 Ваш компьютер болен',
#   'letter_date_sent': '17 декабря 2022, 14:22',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1ac'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Logical Border Radius, iA Presenter Identity, Storybook 7.0, Redesigning Twitter, Oldřich Menhart',
#   'letter_date_sent': '17 декабря 2022, 7:13',
#   'letter_text': ['Logical properties typically refer to the inline or block axis, which are different depending on the direction or writing mode.',
#    'Defining the identity of iA Presenter next to iA Writer was a three-year process that went hand-in-hand with the UI development.',
#    'Re-architected codebase for performance, stability, and 100s of improvements.',
#    'As Elon Musk burns down the Twitter we know, will a drastically different user experience emerge from the ashes?',
#    "On the 125th anniversary of his birth a project to digitize some of the Czech designer's iconic typefaces."]},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1ad'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': 'У Вас новое личное сообщение [GeekBrains]',
#   'letter_date_sent': '17 декабря 2022, 3:22',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1ae'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Скидка 300 рублей на первый заказ🍏',
#   'letter_date_sent': '16 декабря 2022, 21:24',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1af'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Адвент-календарь скидок в METRO!',
#   'letter_date_sent': '16 декабря 2022, 19:02',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1b0'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '💬 Обучение за 0 рублей',
#   'letter_date_sent': '16 декабря 2022, 12:53',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1b1'),
#   'letter_sender': 'CSS Weekly',
#   'letter_theme': 'Issue #534: The State of CSS 2022, CSS image()',
#   'letter_date_sent': '16 декабря 2022, 5:51',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1b2'),
#   'letter_sender': 'Namecheap',
#   'letter_theme': 'How to manage your website like a pro, for less',
#   'letter_date_sent': '15 декабря 2022, 20:48',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1b3'),
#   'letter_sender': 'METRO',
#   'letter_theme': '👉 Скидки до -50% на алкогольные подарочные наборы!',
#   'letter_date_sent': '15 декабря 2022, 17:36',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1b4'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Freeform, :has() Selector, Hierarchy Strips, Design System Maturity, Dataviz a11y',
#   'letter_date_sent': '15 декабря 2022, 16:11',
#   'letter_text': ['Freeform for iPhone, iPad, and Mac makes visual collaboration easier than ever.',
#    'The :has() selector is way more than just a “parent selector”…',
#    'Show that you understand the WHY of your visual work.',
#    'Building a design system is not easy. It requires coordinating across multiple teams and their needs.',
#    'This guide from the Urban Institute provides in-depth lessons on how to create visualization products that are more accessible.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1b5'),
#   'letter_sender': 'METRO',
#   'letter_theme': '👉 Скидки до -50% на алкогольные подарочные наборы!',
#   'letter_date_sent': '15 декабря 2022, 16:04',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1b6'),
#   'letter_sender': 'METRO',
#   'letter_theme': 'Продлеваем действие неиспользованных купонов по 30.12!',
#   'letter_date_sent': '15 декабря 2022, 15:37',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1b7'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '🔴 ИТ-навыки для роста доходов в 2023 году',
#   'letter_date_sent': '15 декабря 2022, 14:02',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1b8'),
#   'letter_sender': 'GeekBrains',
#   'letter_theme': '💥 Завтра повышение цен!',
#   'letter_date_sent': '14 декабря 2022, 17:18',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1b9'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Holiday Snowtacular, Web Fonts, Midjourney vs. Illustrators, In-Car UX, Dark Mode',
#   'letter_date_sent': '14 декабря 2022, 16:11',
#   'letter_text': ['Join us for a holiday fundraiser live stream with 12 wonderful guests, each discussing a different topic!',
#    'An awesome visual deep dive into font layout shifts, and CSS properties to prevent them.',
#    'An experiment: we repeatedly give a typical work task to both a human artist and a text-to-image AI art generator. Who wins?',
#    'Will the future in-car interaction be CarPlay and Android Auto or a native system?',
#    'Some things to consider before going over to the dark side, and adding dark mode to your product.']},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1ba'),
#   'letter_sender': 'Namecheap',
#   'letter_theme': 'Save up to 92% today in our amazing Holiday Deals!',
#   'letter_date_sent': '14 декабря 2022, 0:23',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1bb'),
#   'letter_sender': 'METRO',
#   'letter_theme': '🥃 Скидки до -40% на крепкое!',
#   'letter_date_sent': '13 декабря 2022, 18:41',
#   'letter_text': []},
#  {'_id': ObjectId('63d3fd9d200f1fb7b2bab1bc'),
#   'letter_sender': 'Sidebar',
#   'letter_theme': 'Article Layout, Type & Readability, Polypane 12, Inspirational Websites, 2023 Trends',
#   'letter_date_sent': '13 декабря 2022, 16:11',
#   'letter_text': ['An exploration of how a frontend developer thinks while building an article layout.',
#    'Reading is what we do, and readability refers to qualities of a text that make reading easier.',
#    'Polypane 12 introduces our new command bar and new a11y features and it runs on Chromium 108.',
#    'A new roundup of the most inspiring and creative website from the past couple of weeks.',
#    'The rise of motion design, parallax, immersion, contrasting UI styles, imitations and more.']}]

# %%
print(client.list_database_names())
# Out:
# ['admin', 'config', 'local', 'mail_ru']
